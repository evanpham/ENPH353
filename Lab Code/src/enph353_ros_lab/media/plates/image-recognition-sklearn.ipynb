# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()

print(clf)

from google.colab import drive
drive.mount('/content/drive/')

PATH = "/content/drive/My Drive/ENPH353/enph353_cnn_lab/pictures/"

def files_in_folder(folder_path):
  import re
  '''
  Returns a list of strings where each entry is a file in the folder_path.
  
  Parameters
  ----------
  
  folder_path : str
     A string to folder for which the file listing is returned.
     
  '''
  files_A = !ls "{folder_path}"
  # The files when listed from Google Drive have a particular format. They are
  # grouped in sets of 4 and have spaces and tabs as delimiters.
  
  # Split the string listing sets of 4 files by tab and space and remove any 
  # empty splits.
  files_B = [list(filter(None, re.split('\t|\s', files))) for files in files_A]
  
  # Concatenate all splits into a single sorted list
  files_C = []
  for element in files_B:
    files_C = files_C + element
  files_C.sort()
  
  return files_C
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators='warn',
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import cv2 as cv
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

clf = RandomForestClassifier(n_estimators = 100)
img_files = files_in_folder(PATH)
Labels = [F[0] for F in img_files]
enc = LabelEncoder()
Classes = enc.fit_transform(Labels)
Frames = [np.array(cv.imread(PATH + '/' + F)) for F in img_files]
#Frames = [cv.resize(x, (64,64)) for x in Frames]
Frames = np.stack(Frames)
Frames = Frames.reshape(Frames.shape[1]*Frames.shape[2]*Frames.shape[3], Frames.shape[0]).T
nFrames = Frames/255
#xtrain, xtest, ytrain, ytest = train_test_split(nFrames, Classes, test_size = 0.1)

#clf.fit(xtrain, ytrain)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-c8da7d809fb3> in <module>()
#      11 enc = LabelEncoder()
#      12 Classes = enc.fit_transform(Labels)
# ---> 13 Frames = [np.array(cv.imread(PATH + '/' + F)) for F in img_files]
#      14 #Frames = [cv.resize(x, (64,64)) for x in Frames]
#      15 Frames = np.stack(Frames)
#
# <ipython-input-47-c8da7d809fb3> in <listcomp>(.0)
#      11 enc = LabelEncoder()
#      12 Classes = enc.fit_transform(Labels)
# ---> 13 Frames = [np.array(cv.imread(PATH + '/' + F)) for F in img_files]
#      14 #Frames = [cv.resize(x, (64,64)) for x in Frames]
#      15 Frames = np.stack(Frames)
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import accuracy_score
testp = clf.predict(xtest)
trainp = clf.predict(xtrain)
acc_test =accuracy_score(testp, ytest)
acc_train = accuracy_score(trainp,ytrain)
print(acc, acc_train)
print (testp - ytest)

# %%
l = files_in_folder(PATH)
l
# Out:
# ['plate_AA13.png',
#  'plate_AA60.png',
#  'plate_AA71.png',
#  'plate_AA78.png',
#  'plate_AB39.png',
#  'plate_AC01.png',
#  'plate_AC52.png',
#  'plate_AD07.png',
#  'plate_AD56.png',
#  'plate_AG30.png',
#  'plate_AH64.png',
#  'plate_AJ04.png',
#  'plate_AJ12.png',
#  'plate_AJ50.png',
#  'plate_AK04.png',
#  'plate_AK21.png',
#  'plate_AL01.png',
#  'plate_AL70.png',
#  'plate_AM40.png',
#  'plate_AO27.png',
#  'plate_AO56.png',
#  'plate_AP22.png',
#  'plate_AQ05.png',
#  'plate_AR45.png',
#  'plate_AT74.png',
#  'plate_AT76.png',
#  'plate_AT95.png',
#  'plate_AU28.png',
#  'plate_AV66.png',
#  'plate_AV79.png',
#  'plate_AW46.png',
#  'plate_AX02.png',
#  'plate_AZ57.png',
#  'plate_AZ72.png',
#  'plate_AZ89.png',
#  'plate_BA47.png',
#  'plate_BA69.png',
#  'plate_BA86.png',
#  'plate_BB07.png',
#  'plate_BE28.png',
#  'plate_BE77.png',
#  'plate_BF17.png',
#  'plate_BF50.png',
#  'plate_BF68.png',
#  'plate_BF69.png',
#  'plate_BG68.png',
#  'plate_BH09.png',
# ...
